# %%
import adlfs
import getpass
import azure.storage.blob
import io
import sys
import requests

# %%
#!export AZURE_STORAGE_ACCOUNT=snowmelt
#!export AZURE_STORAGE_SAS_TOKEN="se=2023-02-13T19%3A15Z&sp=racwdl&sv=2018-11-09&sr=c&skoid=b4d39ccb-ca9c-4e9d-a183-5e0f3ba3e609&sktid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2&skt=2023-02-06T19%3A16%3A18Z&ske=2023-02-13T19%3A15%3A00Z&sks=b&skv=2018-11-09&sig=z/AIiFdLunJ/tg9i/gJUqvLRgRxghWgXiIyAm1sV2Zo%3D"
#!gdalinfo /vsiaz/snowmelt/ndvi-wb.tif

# %%
sas_token = 'se=2023-03-06T02%3A45Z&sp=racwdl&sv=2018-11-09&sr=c&skoid=b4d39ccb-ca9c-4e9d-a183-5e0f3ba3e609&sktid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2&skt=2023-02-27T23%3A04%3A11Z&ske=2023-03-06T02%3A45%3A00Z&sks=b&skv=2018-11-09&sig=foscauRfnuTGG//8wOeOu%2BFBoa5IuYUDnYIrqu%2BBzuQ%3D'

# %%
fs = adlfs.AzureBlobFileSystem(account_name="snowmelt", credential=sas_token, anon=False)
fs.ls('snowmelt/eric/MGRS/13UEP/')
# Out:
# ['snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2015_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2015_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2016_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2017_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2017_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2018_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2018_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2019_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2019_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2020_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2020_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2021_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2021_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2022_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2022_median_80m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_corr_strength_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_median_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_polyfit_40m.tif',
#  'snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_std_40m.tif']

# %%
import adlfs
# use read only token
sas_token = 'se=2023-03-06T02%3A45Z&sp=racwdl&sv=2018-11-09&sr=c&skoid=b4d39ccb-ca9c-4e9d-a183-5e0f3ba3e609&sktid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2&skt=2023-02-27T23%3A04%3A11Z&ske=2023-03-06T02%3A45%3A00Z&sks=b&skv=2018-11-09&sig=foscauRfnuTGG//8wOeOu%2BFBoa5IuYUDnYIrqu%2BBzuQ%3D'
tile_names = [tile[-5:] for tile in adlfs.AzureBlobFileSystem(account_name="snowmelt", credential=sas_token, anon=False).ls('snowmelt/eric/MGRS/')]

# %%
#tile_names

# %%
#fs.delete("snowmelt/eric/MGRS/10TGM/runoff_onset_10TGM_2022_median_40m.tif'")
#fs.delete("snowmelt/eric/MGRS/12SXC/", recursive=True)

# %%
fs.delete("snowmelt/eric/MGRS/*/*80m.tif")

# %%
#with io.BytesIO() as buffer:
#    ts_ds.isel(time=0).isel(band=0).rio.to_raster(buffer, driver="COG")
#    buffer.seek(0)
#    blob_client = container_client.get_blob_client(f"eric/mgrs/{}")
#    blob_client.upload_blob(buffer, overwrite=True)

# %%
#sas_token = getpass.getpass()  # prompts for the sas_token
sas_token = "se=2023-02-20T20%3A51Z&sp=racwdl&sv=2018-11-09&sr=c&skoid=b4d39ccb-ca9c-4e9d-a183-5e0f3ba3e609&sktid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2&skt=2023-02-13T20%3A52%3A06Z&ske=2023-02-20T20%3A51%3A00Z&sks=b&skv=2018-11-09&sig=C4rfs7%2BUt5kqABSyxX8qZ0R%2Bbuh9CMlRrYvRN1VtSwc%3D"
container_client = azure.storage.blob.ContainerClient(
    "https://snowmelt.blob.core.windows.net",
    container_name="snowmelt",
    credential=sas_token,
)

# %%
file_list = [item['name'] for item in list(container_client.list_blobs())]

# %%
file_list

# %%
#!gdalinfo "https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/12TYM/runoff_onset_12TYM_2019_median_40m.tif"
#!gdalinfo 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/10UEV/runoff_onset_10UEV_2017_median_80m.tif'
# !gdalinfo 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UDP/runoff_onset_13UDP_2016_median_80m.tif'
# Out:
# Driver: GTiff/GeoTIFF
# Files: none associated
# Size is 1372, 1372
# Coordinate System is:
# PROJCRS["WGS 84 / UTM zone 13N",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 13N",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-105,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     USAGE[
#         SCOPE["Engineering survey, topographic mapping."],
#         AREA["Between 108°W and 102°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - Northwest Territories (NWT); Nunavut; Saskatchewan. Mexico. United States (USA)."],
#         BBOX[0,-108,84,-102]],
#     ID["EPSG",32613]]
# Data axis to CRS axis mapping: 1,2
# Origin = (400000.000000000000000,5400000.000000000000000)
# Pixel Size = (80.000000000000000,-80.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=BAND
#   LAYOUT=COG
# Corner Coordinates:
# Upper Left  (  400000.000, 5400000.000) (106d21'37.01"W, 48d44'41.94"N)
# Lower Left  (  400000.000, 5290240.000) (106d20' 3.63"W, 47d45'27.97"N)
# Upper Right (  509760.000, 5400000.000) (104d52' 1.98"W, 48d45'10.57"N)
# Lower Right (  509760.000, 5290240.000) (104d52'11.10"W, 47d45'55.63"N)
# Center      (  454880.000, 5345120.000) (105d36'28.43"W, 48d15'27.66"N)
# Band 1 Block=512x512 Type=Int16, ColorInterp=Gray
#   Description = dayofyear
#   NoData Value=-32768
#   Overviews: 686x686, 343x343

# %%
URL = 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_2020_median_80m.tif'
#URL = 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_median_80m.tif'
#URL = 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_std_80m.tif'
#URL = 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UEP/runoff_onset_13UEP_allyears_corr_strength_80m.tif'
#URL = 'https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/10SFJ/runoff_onset_10SFJ_2021_median_80m.tif'

# %%
# !gdalinfo $URL
# Out:
# Driver: GTiff/GeoTIFF
# Files: none associated
# Size is 1372, 1373
# Coordinate System is:
# PROJCRS["WGS 84 / UTM zone 13N",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 13N",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-105,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     USAGE[
#         SCOPE["Engineering survey, topographic mapping."],
#         AREA["Between 108°W and 102°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - Northwest Territories (NWT); Nunavut; Saskatchewan. Mexico. United States (USA)."],
#         BBOX[0,-108,84,-102]],
#     ID["EPSG",32613]]
# Data axis to CRS axis mapping: 1,2
# Origin = (500000.000000000000000,5400000.000000000000000)
# Pixel Size = (80.000000000000000,-80.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=BAND
#   LAYOUT=COG
# Corner Coordinates:
# Upper Left  (  500000.000, 5400000.000) (105d 0' 0.00"W, 48d45'10.85"N)
# Lower Left  (  500000.000, 5290160.000) (105d 0' 0.00"W, 47d45'53.30"N)
# Upper Right (  609760.000, 5400000.000) (103d30'25.21"W, 48d44'36.03"N)
# Lower Right (  609760.000, 5290160.000) (103d32' 7.76"W, 47d45'19.66"N)
# Center      (  554880.000, 5345080.000) (104d15'38.24"W, 48d15'23.59"N)
# Band 1 Block=512x512 Type=Int16, ColorInterp=Gray
#   Description = dayofyear
#   NoData Value=-32768
#   Overviews: 686x686, 343x343

# %%
response = requests.head(URL, allow_redirects=True)
size = response.headers.get('content-length', -1)
print('{:<40}: {:.2f} MB'.format('FILE SIZE', int(size) / float(1 << 20)))

# %%
import rioxarray as rxr

# %%
m80 = rxr.open_rasterio('https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/13UDP/runoff_onset_13UDP_2016_median_80m.tif',mask_and_scale=True)
#m40 = rxr.open_rasterio('https://snowmelt.blob.core.windows.net/snowmelt/eric/MGRS/10UEV/runoff_onset_10UEV_2017_median_40m.tif')

# %%
m80
# Out:
# <xarray.DataArray (band: 1, y: 1372, x: 1372)>
# [1882384 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 4e+05 4.001e+05 4.002e+05 ... 5.096e+05 5.097e+05
#   * y            (y) float64 5.4e+06 5.4e+06 5.4e+06 ... 5.29e+06 5.29e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     long_name:      dayofyear

# %%
# !conda create -y -n azure python
# !conda activate azure
# !pip install azure-cli
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/azure
#
#   added / updated specs:
#     - python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     ld_impl_linux-64-2.40      |       h41732ed_0         688 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-ng-12.2.0           |      h65d4601_19         931 KB  conda-forge
#     libgomp-12.2.0             |      h65d4601_19         455 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libsqlite-3.40.0           |       h753d276_0         791 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libzlib-1.2.13             |       h166bdaf_4          64 KB  conda-forge
#     ncurses-6.3                |       h27087fc_1        1002 KB  conda-forge
#     openssl-3.0.8              |       h0b41bf4_0         2.5 MB  conda-forge
#     pip-23.0.1                 |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     python-3.11.0              |he550d4f_1_cpython        30.0 MB  conda-forge
#     readline-8.1.2             |       h0f457ee_0         291 KB  conda-forge
#     setuptools-67.6.0          |     pyhd8ed1ab_0         566 KB  conda-forge
#     tk-8.6.12                  |       h27826a3_0         3.3 MB  conda-forge
#     tzdata-2022g               |       h191b570_0         106 KB  conda-forge
#     wheel-0.38.4               |     pyhd8ed1ab_0          32 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        43.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   ca-certificates    conda-forge/linux-64::ca-certificates-2022.12.7-ha878542_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.2.0-h65d4601_19
#   libgomp            conda-forge/linux-64::libgomp-12.2.0-h65d4601_19
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.40.0-h753d276_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   ncurses            conda-forge/linux-64::ncurses-6.3-h27087fc_1
#   openssl            conda-forge/linux-64::openssl-3.0.8-h0b41bf4_0
#   pip                conda-forge/noarch::pip-23.0.1-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.11.0-he550d4f_1_cpython
#   readline           conda-forge/linux-64::readline-8.1.2-h0f457ee_0
#   setuptools         conda-forge/noarch::setuptools-67.6.0-pyhd8ed1ab_0
#   tk                 conda-forge/linux-64::tk-8.6.12-h27826a3_0
#   tzdata             conda-forge/noarch::tzdata-2022g-h191b570_0
#   wheel              conda-forge/noarch::wheel-0.38.4-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
# ld_impl_linux-64-2.4 | 688 KB    | ##################################### | 100%
# libsqlite-3.40.0     | 791 KB    | ##################################### | 100%
# tk-8.6.12            | 3.3 MB    | ##################################### | 100%
# libzlib-1.2.13       | 64 KB     | ##################################### | 100%
# tzdata-2022g         | 106 KB    | ##################################### | 100%
# python-3.11.0        | 30.0 MB   | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# ca-certificates-2022 | 143 KB    | ##################################### | 100%
# libffi-3.4.2         | 57 KB     | ##################################### | 100%
# readline-8.1.2       | 291 KB    | ##################################### | 100%
# wheel-0.38.4         | 32 KB     | ##################################### | 100%
# libnsl-2.0.0         | 31 KB     | ##################################### | 100%
# setuptools-67.6.0    | 566 KB    | ##################################### | 100%
# xz-5.2.6             | 409 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
# pip-23.0.1           | 1.3 MB    | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# openssl-3.0.8        | 2.5 MB    | ##################################### | 100%
# libgomp-12.2.0       | 455 KB    | ##################################### | 100%
# libgcc-ng-12.2.0     | 931 KB    | ##################################### | 100%
# ncurses-6.3          | 1002 KB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate azure
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# Collecting azure-cli
#   Downloading azure_cli-2.46.0-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 52.5 MB/s eta 0:00:0000:0100:01
# Collecting azure-mgmt-containerservice~=21.2.0
#   Downloading azure_mgmt_containerservice-21.2.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.2 MB/s eta 0:00:0000:01:00:01
# Collecting antlr4-python3-runtime~=4.9.3
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting azure-mgmt-apimanagement~=3.0.0
#   Using cached azure_mgmt_apimanagement-3.0.0-py3-none-any.whl (588 kB)
# Collecting azure-mgmt-storage~=21.0.0
#   Using cached azure_mgmt_storage-21.0.0-py3-none-any.whl (2.8 MB)
# Collecting azure-mgmt-resource==21.1.0b1
#   Using cached azure_mgmt_resource-21.1.0b1-py3-none-any.whl (1.8 MB)
# Collecting azure-mgmt-keyvault==10.1.0
#   Using cached azure_mgmt_keyvault-10.1.0-py3-none-any.whl (605 kB)
# Collecting azure-loganalytics~=0.1.0
#   Using cached azure_loganalytics-0.1.1-py2.py3-none-any.whl (16 kB)
# Collecting azure-multiapi-storage~=1.0.0
#   Using cached azure_multiapi_storage-1.0.0-py2.py3-none-any.whl (2.8 MB)
# Collecting azure-cosmos>=3.0.2,~=3.0
#   Using cached azure_cosmos-3.2.0-py2.py3-none-any.whl (106 kB)
# Collecting PyMySQL~=1.0.2
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Collecting azure-mgmt-relay~=0.1.0
#   Using cached azure_mgmt_relay-0.1.0-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: azure-datalake-store~=0.0.49 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (0.0.51)
# Collecting azure-mgmt-servicelinker==1.2.0b1
#   Using cached azure_mgmt_servicelinker-1.2.0b1-py3-none-any.whl (90 kB)
# Collecting azure-mgmt-msi~=7.0.0
#   Downloading azure_mgmt_msi-7.0.0-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (1.16.0)
# Collecting azure-mgmt-signalr==1.1.0
#   Using cached azure_mgmt_signalr-1.1.0-py3-none-any.whl (83 kB)
# Requirement already satisfied: PyNaCl~=1.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (1.5.0)
# Collecting websocket-client~=1.3.1
#   Using cached websocket_client-1.3.3-py3-none-any.whl (54 kB)
# Collecting azure-mgmt-iothub==2.3.0
#   Using cached azure_mgmt_iothub-2.3.0-py3-none-any.whl (1.0 MB)
# Collecting azure-mgmt-sql==4.0.0b8
#   Downloading azure_mgmt_sql-4.0.0b8-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.0 MB/s eta 0:00:00
# Collecting azure-keyvault~=1.1.0
#   Using cached azure_keyvault-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting azure-mgmt-policyinsights~=1.1.0b2
#   Using cached azure_mgmt_policyinsights-1.1.0b4-py3-none-any.whl (127 kB)
# Collecting sshtunnel~=0.1.4
#   Using cached sshtunnel-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting azure-mgmt-maps~=2.0.0
#   Using cached azure_mgmt_maps-2.0.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-mgmt-iotcentral~=10.0.0b1
#   Using cached azure_mgmt_iotcentral-10.0.0b2-py3-none-any.whl (55 kB)
# Collecting azure-cli-core==2.46.0
#   Downloading azure_cli_core-2.46.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.2/239.2 kB 14.5 MB/s eta 0:00:00
# Collecting azure-mgmt-marketplaceordering==1.1.0
#   Using cached azure_mgmt_marketplaceordering-1.1.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging>=20.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (21.3)
# Collecting azure-mgmt-web==7.0.0
#   Using cached azure_mgmt_web-7.0.0-py3-none-any.whl (4.2 MB)
# Collecting azure-mgmt-network~=21.0.1
#   Using cached azure_mgmt_network-21.0.1-py3-none-any.whl (8.9 MB)
# Collecting azure-mgmt-billing==6.0.0
#   Using cached azure_mgmt_billing-6.0.0-py2.py3-none-any.whl (166 kB)
# Collecting azure-mgmt-managedservices~=1.0
#   Using cached azure_mgmt_managedservices-1.0.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-mgmt-netapp~=9.0.1
#   Using cached azure_mgmt_netapp-9.0.1-py3-none-any.whl (198 kB)
# Requirement already satisfied: colorama~=0.4.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (0.4.4)
# Collecting azure-mgmt-devtestlabs~=4.0
#   Using cached azure_mgmt_devtestlabs-4.0.0-py2.py3-none-any.whl (137 kB)
# Collecting azure-mgmt-compute~=29.1.0
#   Using cached azure_mgmt_compute-29.1.0-py3-none-any.whl (7.2 MB)
# Collecting azure-appconfiguration~=1.1.1
#   Using cached azure_appconfiguration-1.1.1-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-kusto~=0.3.0
#   Using cached azure_mgmt_kusto-0.3.0-py2.py3-none-any.whl (73 kB)
# Collecting jsondiff~=2.0.0
#   Using cached jsondiff-2.0.0-py3-none-any.whl (6.6 kB)
# Collecting azure-mgmt-containerinstance~=10.1.0b1
#   Downloading azure_mgmt_containerinstance-10.1.0b1-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.3 MB/s eta 0:00:00
# Collecting fabric~=2.4
#   Using cached fabric-2.7.1-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-servicebus~=8.2.0
#   Downloading azure_mgmt_servicebus-8.2.0-py3-none-any.whl (940 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 940.1/940.1 kB 32.2 MB/s eta 0:00:00
# Collecting azure-mgmt-eventgrid==10.2.0b2
#   Using cached azure_mgmt_eventgrid-10.2.0b2-py3-none-any.whl (248 kB)
# Collecting azure-mgmt-managementgroups~=1.0.0
#   Using cached azure_mgmt_managementgroups-1.0.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-mgmt-batchai==7.0.0b1
#   Using cached azure_mgmt_batchai-7.0.0b1-py2.py3-none-any.whl (99 kB)
# Collecting azure-mgmt-recoveryservices~=2.2.0
#   Using cached azure_mgmt_recoveryservices-2.2.0-py3-none-any.whl (109 kB)
# Collecting azure-mgmt-monitor~=5.0.0
#   Using cached azure_mgmt_monitor-5.0.1-py3-none-any.whl (1.1 MB)
# Collecting azure-storage-common~=1.4
#   Using cached azure_storage_common-1.4.2-py2.py3-none-any.whl (47 kB)
# Collecting azure-mgmt-imagebuilder~=1.1.0
#   Using cached azure_mgmt_imagebuilder-1.1.0-py3-none-any.whl (44 kB)
# Collecting azure-mgmt-servicefabricmanagedclusters~=1.0.0
#   Using cached azure_mgmt_servicefabricmanagedclusters-1.0.0-py2.py3-none-any.whl (112 kB)
# Collecting azure-mgmt-recoveryservicesbackup~=5.1.0
#   Using cached azure_mgmt_recoveryservicesbackup-5.1.0-py3-none-any.whl (571 kB)
# Collecting azure-mgmt-cognitiveservices~=13.3.0
#   Using cached azure_mgmt_cognitiveservices-13.3.0-py3-none-any.whl (123 kB)
# Collecting azure-mgmt-privatedns~=1.0.0
#   Using cached azure_mgmt_privatedns-1.0.0-py2.py3-none-any.whl (43 kB)
# Collecting azure-mgmt-sqlvirtualmachine==1.0.0b5
#   Downloading azure_mgmt_sqlvirtualmachine-1.0.0b5-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 5.9 MB/s eta 0:00:00
# Collecting azure-mgmt-appconfiguration==2.2.0
#   Using cached azure_mgmt_appconfiguration-2.2.0-py3-none-any.whl (146 kB)
# Collecting azure-mgmt-botservice~=2.0.0b3
#   Using cached azure_mgmt_botservice-2.0.0-py3-none-any.whl (126 kB)
# Collecting azure-mgmt-eventhub~=10.1.0
#   Using cached azure_mgmt_eventhub-10.1.0-py3-none-any.whl (598 kB)
# Collecting azure-mgmt-extendedlocation==1.0.0b2
#   Using cached azure_mgmt_extendedlocation-1.0.0b2-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-consumption~=2.0
#   Using cached azure_mgmt_consumption-2.0.0-py2.py3-none-any.whl (46 kB)
# Collecting azure-mgmt-redis~=14.1.0
#   Using cached azure_mgmt_redis-14.1.0-py3-none-any.whl (112 kB)
# Collecting azure-mgmt-dns~=8.0.0
#   Using cached azure_mgmt_dns-8.0.0-py2.py3-none-any.whl (118 kB)
# Collecting azure-mgmt-advisor==9.0.0
#   Using cached azure_mgmt_advisor-9.0.0-py2.py3-none-any.whl (46 kB)
# Collecting azure-mgmt-containerregistry==10.1.0
#   Downloading azure_mgmt_containerregistry-10.1.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 33.8 MB/s eta 0:00:0000:01
# Collecting azure-synapse-spark~=0.2.0
#   Using cached azure_synapse_spark-0.2.0-py2.py3-none-any.whl (29 kB)
# Collecting azure-mgmt-cosmosdb==9.0.0
#   Downloading azure_mgmt_cosmosdb-9.0.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.0/402.0 kB 19.9 MB/s eta 0:00:00
# Collecting azure-mgmt-cdn==12.0.0
#   Using cached azure_mgmt_cdn-12.0.0-py3-none-any.whl (239 kB)
# Collecting azure-synapse-accesscontrol~=0.5.0
#   Using cached azure_synapse_accesscontrol-0.5.0-py2.py3-none-any.whl (30 kB)
# Collecting azure-synapse-managedprivateendpoints~=0.4.0
#   Downloading azure_synapse_managedprivateendpoints-0.4.0-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.6 MB/s eta 0:00:00
# Collecting azure-mgmt-applicationinsights~=1.0.0
#   Using cached azure_mgmt_applicationinsights-1.0.0-py2.py3-none-any.whl (302 kB)
# Collecting azure-mgmt-servicefabric~=1.0.0
#   Using cached azure_mgmt_servicefabric-1.0.0-py2.py3-none-any.whl (139 kB)
# Collecting azure-keyvault-keys==4.8.0b2
#   Using cached azure_keyvault_keys-4.8.0b2-py3-none-any.whl (442 kB)
# Requirement already satisfied: azure-data-tables==12.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (12.4.0)
# Collecting azure-graphrbac~=0.60.0
#   Using cached azure_graphrbac-0.60.0-py2.py3-none-any.whl (139 kB)
# Collecting azure-mgmt-media~=9.0
#   Using cached azure_mgmt_media-9.0.0-py3-none-any.whl (211 kB)
# Collecting azure-mgmt-loganalytics==13.0.0b4
#   Using cached azure_mgmt_loganalytics-13.0.0b4-py3-none-any.whl (162 kB)
# Collecting azure-synapse-artifacts~=0.15.0
#   Downloading azure_synapse_artifacts-0.15.0-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.2/469.2 kB 21.7 MB/s eta 0:00:00
# Collecting PyGithub~=1.38
#   Downloading PyGithub-1.58.0-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.4/312.4 kB 16.3 MB/s eta 0:00:00
# Collecting azure-batch~=13.0.0
#   Using cached azure_batch-13.0.0-py3-none-any.whl (233 kB)
# Collecting azure-mgmt-databoxedge~=1.0.0
#   Using cached azure_mgmt_databoxedge-1.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting azure-mgmt-synapse==2.1.0b5
#   Using cached azure_mgmt_synapse-2.1.0b5-py3-none-any.whl (547 kB)
# Collecting semver==2.13.0
#   Using cached semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting javaproperties~=0.5.1
#   Using cached javaproperties-0.5.2-py2.py3-none-any.whl (19 kB)
# Collecting azure-mgmt-datalake-store~=0.5.0
#   Using cached azure_mgmt_datalake_store-0.5.0-py2.py3-none-any.whl (88 kB)
# Collecting azure-mgmt-security==3.0.0
#   Using cached azure_mgmt_security-3.0.0-py3-none-any.whl (941 kB)
# Collecting xmltodict~=0.12
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting distro
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting chardet~=3.0.4
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting azure-mgmt-rdbms~=10.2.0b6
#   Using cached azure_mgmt_rdbms-10.2.0b6-py3-none-any.whl (817 kB)
# Collecting azure-mgmt-search~=8.0
#   Using cached azure_mgmt_search-8.0.0-py2.py3-none-any.whl (71 kB)
# Requirement already satisfied: urllib3[secure] in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli) (1.26.11)
# Collecting azure-mgmt-trafficmanager~=1.0.0
#   Using cached azure_mgmt_trafficmanager-1.0.0-py3-none-any.whl (49 kB)
# Collecting scp~=0.13.2
#   Using cached scp-0.13.6-py2.py3-none-any.whl (8.2 kB)
# Collecting azure-mgmt-hdinsight~=9.0.0
#   Using cached azure_mgmt_hdinsight-9.0.0-py2.py3-none-any.whl (125 kB)
# Collecting azure-mgmt-iothubprovisioningservices==1.1.0
#   Using cached azure_mgmt_iothubprovisioningservices-1.1.0-py3-none-any.whl (52 kB)
# Collecting azure-mgmt-authorization~=3.0.0
#   Downloading azure_mgmt_authorization-3.0.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.9/965.9 kB 34.0 MB/s eta 0:00:00
# Collecting azure-mgmt-batch~=17.0.0
#   Using cached azure_mgmt_batch-17.0.0-py3-none-any.whl (157 kB)
# Collecting azure-keyvault-administration==4.0.0b3
#   Using cached azure_keyvault_administration-4.0.0b3-py2.py3-none-any.whl (77 kB)
# Collecting azure-mgmt-datamigration~=10.0.0
#   Using cached azure_mgmt_datamigration-10.0.0-py2.py3-none-any.whl (174 kB)
# Collecting azure-mgmt-datalake-analytics~=0.2.1
#   Using cached azure_mgmt_datalake_analytics-0.2.1-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-redhatopenshift~=1.2.0
#   Using cached azure_mgmt_redhatopenshift-1.2.0-py3-none-any.whl (206 kB)
# Requirement already satisfied: psutil~=5.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (5.9.2)
# Requirement already satisfied: jmespath in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (1.0.1)
# Requirement already satisfied: PyJWT>=2.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (2.4.0)
# Requirement already satisfied: argcomplete~=2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (2.0.0)
# Requirement already satisfied: humanfriendly~=10.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (2.11.0)
# Requirement already satisfied: msrestazure~=0.6.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (0.6.4)
# Collecting pkginfo>=1.5.0.1
#   Using cached pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Requirement already satisfied: cryptography in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (37.0.4)
# Collecting azure-cli-telemetry==1.0.8.*
#   Using cached azure_cli_telemetry-1.0.8-py3-none-any.whl (12 kB)
# Requirement already satisfied: azure-mgmt-core<2,>=1.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (1.3.2)
# Collecting knack~=0.10.1
#   Using cached knack-0.10.1-py3-none-any.whl (61 kB)
# Collecting msal-extensions~=1.0.0
#   Using cached msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pyopenssl>=17.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (22.0.0)
# Collecting msal[broker]==1.20.0
#   Using cached msal-1.20.0-py2.py3-none-any.whl (90 kB)
# Requirement already satisfied: requests[socks] in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-core==2.46.0->azure-cli) (2.28.1)
# Requirement already satisfied: msrest>=0.6.21 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-data-tables==12.4.0->azure-cli) (0.7.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.15.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-data-tables==12.4.0->azure-cli) (1.25.1)
# Requirement already satisfied: azure-common~=1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-keyvault-administration==4.0.0b3->azure-cli) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-keyvault-keys==4.8.0b2->azure-cli) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-keyvault-keys==4.8.0b2->azure-cli) (4.3.0)
# Requirement already satisfied: applicationinsights<0.12,>=0.11.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-cli-telemetry==1.0.8.*->azure-cli-core==2.46.0->azure-cli) (0.11.9)
# Collecting portalocker<3,>=1.6
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: adal>=0.4.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-datalake-store~=0.0.49->azure-cli) (1.2.7)
# Requirement already satisfied: cffi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-datalake-store~=0.0.49->azure-cli) (1.15.1)
# Collecting azure-nspkg>=2.0.0
#   Using cached azure_nspkg-3.0.2-py3-none-any.whl (1.5 kB)
# Collecting azure-mgmt-nspkg>=2.0.0
#   Using cached azure_mgmt_nspkg-3.0.2-py3-none-any.whl (1.6 kB)
# Collecting azure-mgmt-datalake-nspkg>=2.0.0
#   Using cached azure_mgmt_datalake_nspkg-3.0.1-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: python-dateutil in /srv/conda/envs/notebook/lib/python3.10/site-packages (from azure-multiapi-storage~=1.0.0->azure-cli) (2.8.2)
# Collecting pathlib2
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting invoke<2.0,>=1.3
#   Using cached invoke-1.7.3-py3-none-any.whl (216 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging>=20.9->azure-cli) (3.0.9)
# Collecting deprecated
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from urllib3[secure]->azure-cli) (2022.9.14)
# Requirement already satisfied: idna>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from urllib3[secure]->azure-cli) (3.3)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi->azure-datalake-store~=0.0.49->azure-cli) (2.21)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.10/site-packages (from knack~=0.10.1->azure-cli-core==2.46.0->azure-cli) (5.4.1)
# Requirement already satisfied: pygments in /srv/conda/envs/notebook/lib/python3.10/site-packages (from knack~=0.10.1->azure-cli-core==2.46.0->azure-cli) (2.13.0)
# Requirement already satisfied: tabulate in /srv/conda/envs/notebook/lib/python3.10/site-packages (from knack~=0.10.1->azure-cli-core==2.46.0->azure-cli) (0.8.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (1.3.1)
# Requirement already satisfied: bcrypt>=3.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azure-cli-core==2.46.0->azure-cli) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests[socks]->azure-cli-core==2.46.0->azure-cli) (2.1.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from deprecated->PyGithub~=1.38->azure-cli) (1.14.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests[socks]->azure-cli-core==2.46.0->azure-cli) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (3.2.1)
# Installing collected packages: jsondiff, invoke, chardet, azure-nspkg, antlr4-python3-runtime, xmltodict, websocket-client, semver, PyMySQL, portalocker, pkginfo, pathlib2, knack, javaproperties, distro, deprecated, azure-mgmt-nspkg, azure-mgmt-datalake-nspkg, azure-cosmos, azure-cli-telemetry, PyGithub, azure-storage-common, azure-keyvault-keys, sshtunnel, scp, msal, fabric, azure-synapse-spark, azure-synapse-managedprivateendpoints, azure-synapse-artifacts, azure-synapse-accesscontrol, azure-multiapi-storage, azure-mgmt-web, azure-mgmt-trafficmanager, azure-mgmt-synapse, azure-mgmt-storage, azure-mgmt-sqlvirtualmachine, azure-mgmt-sql, azure-mgmt-signalr, azure-mgmt-servicelinker, azure-mgmt-servicefabricmanagedclusters, azure-mgmt-servicefabric, azure-mgmt-servicebus, azure-mgmt-security, azure-mgmt-search, azure-mgmt-resource, azure-mgmt-redis, azure-mgmt-redhatopenshift, azure-mgmt-recoveryservicesbackup, azure-mgmt-recoveryservices, azure-mgmt-rdbms, azure-mgmt-privatedns, azure-mgmt-policyinsights, azure-mgmt-network, azure-mgmt-netapp, azure-mgmt-msi, azure-mgmt-monitor, azure-mgmt-media, azure-mgmt-marketplaceordering, azure-mgmt-maps, azure-mgmt-managementgroups, azure-mgmt-loganalytics, azure-mgmt-keyvault, azure-mgmt-iothubprovisioningservices, azure-mgmt-iothub, azure-mgmt-iotcentral, azure-mgmt-imagebuilder, azure-mgmt-hdinsight, azure-mgmt-extendedlocation, azure-mgmt-eventhub, azure-mgmt-eventgrid, azure-mgmt-dns, azure-mgmt-datamigration, azure-mgmt-databoxedge, azure-mgmt-cosmosdb, azure-mgmt-containerservice, azure-mgmt-containerregistry, azure-mgmt-containerinstance, azure-mgmt-compute, azure-mgmt-cognitiveservices, azure-mgmt-cdn, azure-mgmt-botservice, azure-mgmt-billing, azure-mgmt-batchai, azure-mgmt-batch, azure-mgmt-authorization, azure-mgmt-applicationinsights, azure-mgmt-appconfiguration, azure-mgmt-apimanagement, azure-mgmt-advisor, azure-loganalytics, azure-keyvault-administration, azure-appconfiguration, msal-extensions, azure-mgmt-relay, azure-mgmt-managedservices, azure-mgmt-kusto, azure-mgmt-devtestlabs, azure-mgmt-datalake-store, azure-mgmt-datalake-analytics, azure-mgmt-consumption, azure-keyvault, azure-graphrbac, azure-batch, azure-cli-core, azure-cli
#   Attempting uninstall: antlr4-python3-runtime
#     Found existing installation: antlr4-python3-runtime 4.11.1
#     Uninstalling antlr4-python3-runtime-4.11.1:
#       Successfully uninstalled antlr4-python3-runtime-4.11.1
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.4.1
#     Uninstalling websocket-client-1.4.1:
#       Successfully uninstalled websocket-client-1.4.1
#   Attempting uninstall: portalocker
#     Found existing installation: portalocker 1.2.1
#     Uninstalling portalocker-1.2.1:
#       Successfully uninstalled portalocker-1.2.1
#   Attempting uninstall: knack
#     Found existing installation: knack 0.5.1
#     Uninstalling knack-0.5.1:
#       Successfully uninstalled knack-0.5.1
#   Attempting uninstall: azure-cli-telemetry
#     Found existing installation: azure-cli-telemetry 1.0.2
#     Uninstalling azure-cli-telemetry-1.0.2:
#       Successfully uninstalled azure-cli-telemetry-1.0.2
#   Attempting uninstall: msal
#     Found existing installation: msal 1.18.0
#     Uninstalling msal-1.18.0:
#       Successfully uninstalled msal-1.18.0
#   Attempting uninstall: azure-mgmt-resource
#     Found existing installation: azure-mgmt-resource 2.1.0
#     Uninstalling azure-mgmt-resource-2.1.0:
#       Successfully uninstalled azure-mgmt-resource-2.1.0
#   Attempting uninstall: azure-mgmt-network
#     Found existing installation: azure-mgmt-network 16.0.0
#     Uninstalling azure-mgmt-network-16.0.0:
#       Successfully uninstalled azure-mgmt-network-16.0.0
#   Attempting uninstall: azure-mgmt-compute
#     Found existing installation: azure-mgmt-compute 18.2.0
#     Uninstalling azure-mgmt-compute-18.2.0:
#       Successfully uninstalled azure-mgmt-compute-18.2.0
#   Attempting uninstall: msal-extensions
#     Found existing installation: msal-extensions 0.3.0
#     Uninstalling msal-extensions-0.3.0:
#       Successfully uninstalled msal-extensions-0.3.0
#   Attempting uninstall: azure-cli-core
#     Found existing installation: azure-cli-core 2.0.61
#     Uninstalling azure-cli-core-2.0.61:
#       Successfully uninstalled azure-cli-core-2.0.61
# Successfully installed PyGithub-1.58.0 PyMySQL-1.0.2 antlr4-python3-runtime-4.9.3 azure-appconfiguration-1.1.1 azure-batch-13.0.0 azure-cli-2.46.0 azure-cli-core-2.46.0 azure-cli-telemetry-1.0.8 azure-cosmos-3.2.0 azure-graphrbac-0.60.0 azure-keyvault-1.1.0 azure-keyvault-administration-4.0.0b3 azure-keyvault-keys-4.8.0b2 azure-loganalytics-0.1.1 azure-mgmt-advisor-9.0.0 azure-mgmt-apimanagement-3.0.0 azure-mgmt-appconfiguration-2.2.0 azure-mgmt-applicationinsights-1.0.0 azure-mgmt-authorization-3.0.0 azure-mgmt-batch-17.0.0 azure-mgmt-batchai-7.0.0b1 azure-mgmt-billing-6.0.0 azure-mgmt-botservice-2.0.0 azure-mgmt-cdn-12.0.0 azure-mgmt-cognitiveservices-13.3.0 azure-mgmt-compute-29.1.0 azure-mgmt-consumption-2.0.0 azure-mgmt-containerinstance-10.1.0b1 azure-mgmt-containerregistry-10.1.0 azure-mgmt-containerservice-21.2.0 azure-mgmt-cosmosdb-9.0.0 azure-mgmt-databoxedge-1.0.0 azure-mgmt-datalake-analytics-0.2.1 azure-mgmt-datalake-nspkg-3.0.1 azure-mgmt-datalake-store-0.5.0 azure-mgmt-datamigration-10.0.0 azure-mgmt-devtestlabs-4.0.0 azure-mgmt-dns-8.0.0 azure-mgmt-eventgrid-10.2.0b2 azure-mgmt-eventhub-10.1.0 azure-mgmt-extendedlocation-1.0.0b2 azure-mgmt-hdinsight-9.0.0 azure-mgmt-imagebuilder-1.1.0 azure-mgmt-iotcentral-10.0.0b2 azure-mgmt-iothub-2.3.0 azure-mgmt-iothubprovisioningservices-1.1.0 azure-mgmt-keyvault-10.1.0 azure-mgmt-kusto-0.3.0 azure-mgmt-loganalytics-13.0.0b4 azure-mgmt-managedservices-1.0.0 azure-mgmt-managementgroups-1.0.0 azure-mgmt-maps-2.0.0 azure-mgmt-marketplaceordering-1.1.0 azure-mgmt-media-9.0.0 azure-mgmt-monitor-5.0.1 azure-mgmt-msi-7.0.0 azure-mgmt-netapp-9.0.1 azure-mgmt-network-21.0.1 azure-mgmt-nspkg-3.0.2 azure-mgmt-policyinsights-1.1.0b4 azure-mgmt-privatedns-1.0.0 azure-mgmt-rdbms-10.2.0b6 azure-mgmt-recoveryservices-2.2.0 azure-mgmt-recoveryservicesbackup-5.1.0 azure-mgmt-redhatopenshift-1.2.0 azure-mgmt-redis-14.1.0 azure-mgmt-relay-0.1.0 azure-mgmt-resource-21.1.0b1 azure-mgmt-search-8.0.0 azure-mgmt-security-3.0.0 azure-mgmt-servicebus-8.2.0 azure-mgmt-servicefabric-1.0.0 azure-mgmt-servicefabricmanagedclusters-1.0.0 azure-mgmt-servicelinker-1.2.0b1 azure-mgmt-signalr-1.1.0 azure-mgmt-sql-4.0.0b8 azure-mgmt-sqlvirtualmachine-1.0.0b5 azure-mgmt-storage-21.0.0 azure-mgmt-synapse-2.1.0b5 azure-mgmt-trafficmanager-1.0.0 azure-mgmt-web-7.0.0 azure-multiapi-storage-1.0.0 azure-nspkg-3.0.2 azure-storage-common-1.4.2 azure-synapse-accesscontrol-0.5.0 azure-synapse-artifacts-0.15.0 azure-synapse-managedprivateendpoints-0.4.0 azure-synapse-spark-0.2.0 chardet-3.0.4 deprecated-1.2.13 distro-1.8.0 fabric-2.7.1 invoke-1.7.3 javaproperties-0.5.2 jsondiff-2.0.0 knack-0.10.1 msal-1.20.0 msal-extensions-1.0.0 pathlib2-2.3.7.post1 pkginfo-1.9.6 portalocker-2.7.0 scp-0.13.6 semver-2.13.0 sshtunnel-0.1.5 websocket-client-1.3.3 xmltodict-0.13.0

# %%
# !az login
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CYU59KKZZ to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "f6b6dd5b-f02f-441a-99a0-162ac5060bd2",
#     "id": "c8a2ce97-0a74-4a49-ba34-7c8d529837a6",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "rob5 main",
#     "state": "Enabled",
#     "tenantId": "f6b6dd5b-f02f-441a-99a0-162ac5060bd2",
#     "user": {
#       "name": "egagli@uw.edu",
#       "type": "user"
#     }
#   }
# ]

# %%
# !date -u -d "7 days" '+%Y-%m-%dT%H:%MZ'
# Out:
# 2023-03-16T19:21Z

# %%
# NOTE: 7 day max on these tokens
#end=`date -u -d "7 days" '+%Y-%m-%dT%H:%MZ'`

# !az storage container generate-sas \
    --account-name snowmelt\
    --name snowmelt \
    --permissions acdlrw \
    --expiry 2023-03-16T19:21Z \
    --auth-mode login \
    --as-user


# az storage container generate-sas \
#     --account-name snowmelt\
#     --name snowmelt \
#     --permissions rl \
#     --expiry 2023-02-13T19:15Z \
#     --auth-mode login \
#     --as-user
# Out:
# "se=2023-03-16T19%3A21Z&sp=racwdl&sv=2021-06-08&sr=c&skoid=598b2582-4d1d-4c4e-9bb2-3ad571b791b5&sktid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2&skt=2023-03-09T19%3A22%3A04Z&ske=2023-03-16T19%3A21%3A00Z&sks=b&skv=2021-06-08&sig=2bBeUKL3cssK2B5awpBaxKE9VE0hjZ5bhXK8sx4eU0c%3D"
